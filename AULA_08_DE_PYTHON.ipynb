# %% [markdown]
# <a href="https://colab.research.google.com/github/gabis0604/projetos-da-faculdade-linguagem-de-sistemas/blob/main/AULA_08_DE_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##AULA 08

# %%
class Pessoa:
    def __init__(self, nome, idade, genero):
        self.nome = nome
        self.idade = idade
        self.genero = genero

    def cumprimentar(self):
        return f"Olá, meu nome é {self.nome}."

    def aniversaio(self):
        self.idade += 1

# %%
pessoa1 = Pessoa("João", 25, "Masculino")
pessoa2 = Pessoa("Maria", 30, "Feminino")

print(pessoa1.cumprimentar())
print(pessoa2.cumprimentar())
print(f"idade:  {pessoa1.idade}")
print(f"idade:  {pessoa2.idade}")
# Out:
# Olá, meu nome é João.
# Olá, meu nome é Maria.
# idade:  25
# idade:  30

# %%
pessoa1.aniversaio()
pessoa2.aniversaio()
print(f"Nova idade:  {pessoa1.idade}")
print(f"Nova idade:  {pessoa2.idade}")
# Out:
# Nova idade:  26
# Nova idade:  31

# %%
class Animal:
    def __init__(self, nome):
        self.nome = nome

    def fazer_barulho(self):
        pass

class Cachorro(Animal):
    def fazer_barulho(self):
        return "Au au!"

class Gato(Animal):
    def fazer_barulho(self):
        return "Miau!"

# %%
rex = Cachorro("Rex")
margot = Gato("Margot")

# %%
print(f"{rex.nome} faz: {rex.fazer_barulho()}")
print(f"{margot.nome} faz: {margot.fazer_barulho()}")
# Out:
# Rex faz: Au au!
# Margot faz: Miau!

# %%
class Veiculo:
    def __init__(self, marca, modelo, ano):
        self.marca = marca
        self.modelo = modelo
        self.ano = ano
        self.velocidade = 0

    def acelerar(self, incremento):
        self.velocidade += incremento

    def frear(self, decremento):
        self.velocidade -= decremento

    def status(self):
      return (f"Marca: {self.marca}, Modelo: {self.modelo}, Ano: {self.ano}, Velocidade: {self.velocidade} Km/h")

class Carro(Veiculo):
    def __init__(self, marca, modelo, ano, potencia):
        super().__init__(marca, modelo, ano)
        self.potencia = potencia

    def acelerar(self, incremento):
        self.velocidade += incremento + self.potencia

class Bicicleta(Veiculo):
    def __init__(self, marca, modelo, ano, tipo):
        super().__init__(marca, modelo, ano)
        self.tipo = tipo

    def status(self):
        return (f"Marca: {self.marca}, Modelo: {self.modelo}, Ano: {self.ano}, Velocidade: {self.velocidade} Km/h, Tipo: {self.tipo}")

carro1 = Carro("Fox", "Compacto", 2008, 150) # Added 'Compacto' for modelo and '150' for potencia
bicicleta1 = Bicicleta("Caloy", "Mountain Bike", 2023, "MTB") # Corrected modelo, ano, and added tipo

carro1.acelerar(30)
bicicleta1.acelerar(20)

print("Status do carro:")
print(carro1.status())

print("\nStatus da bicicleta:")
print(bicicleta1.status()) # Added parentheses to call the method



#
# Out:
# Status do carro:
# Marca: Fox, Modelo: Compacto, Ano: 2008, Velocidade: 180 Km/h
#
# Status da bicicleta:
# Marca: Caloy, Modelo: Mountain Bike, Ano: 2023, Velocidade: 20 Km/h, Tipo: MTB
